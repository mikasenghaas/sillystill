# %% [markdown]
# # Losses v2

# %% [markdown]
# ## Setup
#
# ---
#
# Let's install some necessary dependencies and set global variables.

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
# Autoroot
import autorootcwd

# %%
# Imports
import torch
from torch.nn import MSELoss
from hydra import compose, initialize
from hydra.utils import instantiate

from src.models.loss import SillyLoss
# Out:
# [autoreload of src.models.loss.frequency failed: Traceback (most recent call last):
#   File "/Users/pierrelardet/anaconda3/envs/sillystill/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/pierrelardet/anaconda3/envs/sillystill/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Users/pierrelardet/anaconda3/envs/sillystill/lib/python3.9/importlib/__init__.py", line 159, in reload
#     raise ImportError(msg.format(parent_name),
# ImportError: parent 'src.models.loss' not in sys.modules
# ]
# [autoreload of src.models.loss.gclm failed: Traceback (most recent call last):
#   File "/Users/pierrelardet/anaconda3/envs/sillystill/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/pierrelardet/anaconda3/envs/sillystill/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Users/pierrelardet/anaconda3/envs/sillystill/lib/python3.9/importlib/__init__.py", line 159, in reload
#     raise ImportError(msg.format(parent_name),
# ImportError: parent 'src.models.loss' not in sys.modules
# ]
# [autoreload of src.models.loss.frequency failed: Traceback (most recent call last):
#   File "/Users/pierrelardet/anaconda3/envs/sillystill/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/pierrelardet/anaconda3/envs/sillystill/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Users/pierrelardet/anaconda3/envs/sillystill/lib/python3.9/importlib/__init__.py", line 159, in reload
#     raise ImportError(msg.format(parent_name),
# ImportError: parent 'src.models.loss' not in sys.modules
# ]
# [autoreload of src.models.loss.gclm failed: Traceback (most recent call last):
#   File "/Users/pierrelardet/anaconda3/envs/sillystill/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/pierrelardet/anaconda3/envs/sillystill/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Users/pierrelardet/anaconda3/envs/sillystill/lib/python3.9/importlib/__init__.py", line 159, in reload
#     raise ImportError(msg.format(parent_name),
# ImportError: parent 'src.models.loss' not in sys.modules
# ]
# [autoreload of src.models.loss.frequency failed: Traceback (most recent call last):
#   File "/Users/pierrelardet/anaconda3/envs/sillystill/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/pierrelardet/anaconda3/envs/sillystill/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Users/pierrelardet/anaconda3/envs/sillystill/lib/python3.9/importlib/__init__.py", line 159, in reload
#     raise ImportError(msg.format(parent_name),
# ImportError: parent 'src.models.loss' not in sys.modules
# ]
# [autoreload of src.models.loss.gclm failed: Traceback (most recent call last):
#   File "/Users/pierrelardet/anaconda3/envs/sillystill/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/pierrelardet/anaconda3/envs/sillystill/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Users/pierrelardet/anaconda3/envs/sillystill/lib/python3.9/importlib/__init__.py", line 159, in reload
#     raise ImportError(msg.format(parent_name),
# ImportError: parent 'src.models.loss' not in sys.modules
# ]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 7
#       4 from hydra import compose, initialize
#       5 from hydra.utils import instantiate
# ----> 7 from src.models.loss import SillyLoss
#
# File ~/sillystill/src/models/__init__.py:2
#       1 from .translation_module import TranslationModule
# ----> 2 from .auto_translation_module import AutoTranslationModule
#       4 __all__ = ["TranslationModule", "AutoTranslationModule"]
#
# File ~/sillystill/src/models/auto_translation_module.py:15
#      12 from torchmetrics.image.lpip import LearnedPerceptualImagePatchSimilarity as LPIPS
#      13 from ..eval import PieAPP
# ---> 15 from .loss.auto_translate import AutoTranslateLoss
#      16 from .net.auto_translate import AutoTranslateNet
#      17 from .base_module import BaseModule
#
# File ~/sillystill/src/models/loss/__init__.py:12
#       9 from .frequency import FrequencyLoss
#      10 from .gclm import GCLMLoss
# ---> 12 from .silly import SillyLoss
#      14 from .auto_translate import AutoTranslateLoss
#
# File ~/sillystill/src/models/loss/silly.py:26
#      22     Frequency = FrequencyLoss
#      23     CoBi = CoBiLoss
# ---> 26 class SillyLoss(nn.Module):
#      27     def __init__(self, losses: list[Loss], weights: list[float]):
#      28         super().__init__()
#
# File ~/anaconda3/envs/sillystill/lib/python3.9/site-packages/torch/__init__.py:1938, in __getattr__(name)
#    1935     import importlib
#    1936     return importlib.import_module(f".{name}", __name__)
# -> 1938 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'torch' has no attribute 'Module'

# %%
x = torch.randn(1, 3, 128, 128)
y = torch.randn(1, 3, 128, 128)

# %% [markdown]
# ### MSE
#
# The `MSELoss` is the mean squared error between two tensors.

# %%
# Initialise `MSELoss`
mse = MSELoss()
loss1, loss2 = mse(x, x), mse(x, y)
assert loss1 < loss2

loss1, loss2

# %% [markdown]
# ### CoBiLoss

# %%
# Initialise `CobiLoss`
cobi = CoBiLoss()
loss1, loss2 = cobi(x, x), cobi(x, y)
assert loss1 < loss2

loss1, loss2

# %% [markdown]
# ### MSE-VGG Loss

# %%
# Initialise `MSEVGGLoss`
mse_vgg = MSEVGGLoss()
loss1, loss2 = mse_vgg(x, x), mse_vgg(x, y)
assert loss1 < loss2

loss1, loss2

# %% [markdown]
# ### AutoTranslateLoss

# %%
# Initialise `AutoTranslateLoss`
auto_translate = AutoTranslateLoss()
# TODO: Show how to use

# %% [markdown]
# ## Hydra

# %%
for loss in ["mse", "cobi", "simple-combined", "auto-translate"]:
    with initialize(version_base=None, config_path="../configs/model/loss", job_name="losses"):
        cfg = compose(config_name=loss)
        loss = instantiate(cfg)
        print(f"✅ Initialised {cfg._target_}")
